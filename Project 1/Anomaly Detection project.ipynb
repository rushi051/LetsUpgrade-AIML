# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from scipy.io import loadmat

# %% [markdown]
# ## Import PyOD Packages

# %%
from pyod.models.pca import  PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#Metrics packages
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %%
mat_files = ["arrhythmia.mat","cardio.mat","glass.mat","ionosphere.mat","letter.mat","lympho.mat",
             "mnist.mat","musk.mat","optdigits.mat","pendigits.mat","pima.mat","satellite.mat","satimage-2.mat",
             "shuttle.mat","vertebral.mat","vowels.mat","wbc.mat"]

# %%
random_state = np.random.RandomState(42)

# %%
df_columns = ['Data','#Samples','#Dimensions','Outlier Perc','ABOD'
             ,'CBLOF','FB','HBOS','IForest','KNN','LOF','MCD','OCSVM','PCA']

roc_df = pd.DataFrame(columns=df_columns)
prn_df = pd.DataFrame(columns=df_columns)
time_df = pd.DataFrame(columns=df_columns)

# %%
data = loadmat('data/cardio.mat')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#          -0.28978574, -0.49329397],
#         [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#          -0.25638541, -0.49329397],
#         [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#          -0.25638541,  1.14001753],
#         ...,
#         [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#           0.24461959, -0.49329397],
#         [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#           0.14441859, -0.49329397],
#         [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#           3.58465295, -0.49329397]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
# Shape and Type of Independent/Input variable
type(data['X']),data['X'].shape
# Out:
# (numpy.ndarray, (1831, 21))

# %%
# Shape and Type of Dependent/Output variable
type(data['y']),data['y'].shape
# Out:
# (numpy.ndarray, (1831, 1))

# %%
roc_df = pd.DataFrame(columns=df_columns)
roc_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, #Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %%
prn_df = pd.DataFrame(columns=df_columns)
prn_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, #Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %%
time_df = pd.DataFrame(columns=df_columns)
time_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, #Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# # Exploring mat files

# %%
from time import time

random_state = np.random.RandomState(42)
for mat_file in mat_files:
    print("/n  Processing",mat_file,". . ./n")
    mat = loadmat(os.path.join('data',mat_file))
    
    X = mat['X']
    y = mat['y'].ravel()
    
    outlier_fraction = np.count_nonzero(y) / len(y)
    outliers_percentage = round(outlier_fraction * 100, ndigits=4)
    
    roc_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    prn_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    time_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=random_state)
    
    X_train_norm,X_test_norm = standardizer(X_train,X_test)
    
    classifiers = {
        'Angle Based Outlier Detection(ABOD)': ABOD(contamination=outlier_fraction),
        'Cluster-Based Local Outlier Factor(CBLOF)':CBLOF(contamination=outlier_fraction,check_estimator=False,
                                                          random_state=random_state),
        'FeatureBagging': FeatureBagging(contamination=outlier_fraction,random_state=random_state),
        'Histogram Based Outlier Detection':HBOS(contamination=outlier_fraction),
        'Isolation Forest': IForest(contamination=outlier_fraction,random_state=random_state),
        'K-Nearest Neighbour': KNN(contamination=outlier_fraction),
        'Local Outleir factor': LOF(contamination=outlier_fraction),
        'Minimum Covariance Determinant': MCD(contamination=outlier_fraction,random_state=random_state),
        'One-Class SVM': OCSVM(contamination=outlier_fraction),
        'Principle Component Analysis':PCA(contamination=outlier_fraction,random_state=random_state),
    }
    
    for clf_name, clf in classifiers.items():
        t0 = time()
        clf.fit(X_train_norm)
        test_score = clf.decision_function(X_test_norm)
        t1 = time()
        duration = round(t1 - t0, ndigits=4)
        time_list.append(duration)
        
        roc = round(roc_auc_score(y_test,test_score),ndigits=4)
        prn = round(precision_n_scores(y_test,test_score),ndigits=4)
        
        print('{clf_name} ROC:{roc}, Precision @ rank n:{prn},''Execution Time:{duration}s'.format
              (clf_name=clf_name,roc=roc,prn=prn,duration=duration))
        
        roc_list.append(roc)
        prn_list.append(prn)        
        
    temp_df = pd.DataFrame(time_list).transpose()
    temp_df.columns = df_columns
    time_df = pd.concat([time_df,temp_df],axis = 0)
        
    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df.columns = df_columns
    roc_df = pd.concat([roc_df,temp_df],axis = 0)
        
    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df.columns = df_columns
    prn_df = pd.concat([prn_df,temp_df],axis = 0)
# Out:
# /n  Processing arrhythmia.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.7687, Precision @ rank n:0.3571,Execution Time:0.1167s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.7684, Precision @ rank n:0.4643,Execution Time:1.2645s
# FeatureBagging ROC:0.7799, Precision @ rank n:0.5,Execution Time:0.4847s
# Histogram Based Outlier Detection ROC:0.8511, Precision @ rank n:0.5714,Execution Time:1.2055s
# Isolation Forest ROC:0.8527, Precision @ rank n:0.5714,Execution Time:0.2962s
# K-Nearest Neighbour ROC:0.782, Precision @ rank n:0.5,Execution Time:0.0708s
# Local Outleir factor ROC:0.7787, Precision @ rank n:0.4643,Execution Time:0.0599s
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant ROC:0.8228, Precision @ rank n:0.4286,Execution Time:0.4248s
# One-Class SVM ROC:0.7986, Precision @ rank n:0.5,Execution Time:0.0489s
# Principle Component Analysis ROC:0.7997, Precision @ rank n:0.5,Execution Time:0.0599s
# /n  Processing cardio.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.5763, Precision @ rank n:0.1875,Execution Time:0.3092s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.8221, Precision @ rank n:0.4844,Execution Time:0.1097s
# FeatureBagging ROC:0.4879, Precision @ rank n:0.1406,Execution Time:0.6243s
# Histogram Based Outlier Detection ROC:0.8453, Precision @ rank n:0.4688,Execution Time:0.006s
# Isolation Forest ROC:0.9414, Precision @ rank n:0.5,Execution Time:0.2912s
# K-Nearest Neighbour ROC:0.6959, Precision @ rank n:0.2812,Execution Time:0.1147s
# Local Outleir factor ROC:0.4715, Precision @ rank n:0.125,Execution Time:0.0768s
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.770956835748848 > -250.696836140088948). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# Minimum Covariance Determinant ROC:0.8778, Precision @ rank n:0.3906,Execution Time:0.4308s
# One-Class SVM ROC:0.9507, Precision @ rank n:0.5938,Execution Time:0.0569s
# Principle Component Analysis ROC:0.9638, Precision @ rank n:0.6875,Execution Time:0.003s
# /n  Processing glass.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.7104, Precision @ rank n:0.25,Execution Time:0.0269s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.8506, Precision @ rank n:0.25,Execution Time:0.0319s
# FeatureBagging ROC:0.7043, Precision @ rank n:0.25,Execution Time:0.0269s
# Histogram Based Outlier Detection ROC:0.6524, Precision @ rank n:0.0,Execution Time:0.003s
# Isolation Forest ROC:0.7195, Precision @ rank n:0.25,Execution Time:0.2384s
# K-Nearest Neighbour ROC:0.7805, Precision @ rank n:0.25,Execution Time:0.007s
# Local Outleir factor ROC:0.7774, Precision @ rank n:0.25,Execution Time:0.003s
# Minimum Covariance Determinant ROC:0.7165, Precision @ rank n:0.0,Execution Time:0.025s
# One-Class SVM ROC:0.6189, Precision @ rank n:0.25,Execution Time:0.0019s
# Principle Component Analysis ROC:0.622, Precision @ rank n:0.25,Execution Time:0.0009s
# /n  Processing ionosphere.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.9004, Precision @ rank n:0.8214,Execution Time:0.0459s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.8952, Precision @ rank n:0.8036,Execution Time:0.0379s
# FeatureBagging ROC:0.8933, Precision @ rank n:0.75,Execution Time:0.0559s
# Histogram Based Outlier Detection ROC:0.5195, Precision @ rank n:0.3393,Execution Time:0.007s
# Isolation Forest ROC:0.8309, Precision @ rank n:0.6607,Execution Time:0.2454s
# K-Nearest Neighbour ROC:0.9134, Precision @ rank n:0.8393,Execution Time:0.014s
# Local Outleir factor ROC:0.8989, Precision @ rank n:0.75,Execution Time:0.005s
# Minimum Covariance Determinant ROC:0.9399, Precision @ rank n:0.8571,Execution Time:0.0549s
# One-Class SVM ROC:0.8372, Precision @ rank n:0.7143,Execution Time:0.006s
# Principle Component Analysis ROC:0.7971, Precision @ rank n:0.5893,Execution Time:0.003s
# /n  Processing letter.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.8465, Precision @ rank n:0.275,Execution Time:0.2693s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.7423, Precision @ rank n:0.175,Execution Time:0.0828s
# FeatureBagging ROC:0.866, Precision @ rank n:0.4,Execution Time:0.5844s
# Histogram Based Outlier Detection ROC:0.5728, Precision @ rank n:0.125,Execution Time:0.008s
# Isolation Forest ROC:0.5778, Precision @ rank n:0.05,Execution Time:0.3002s
# K-Nearest Neighbour ROC:0.845, Precision @ rank n:0.3,Execution Time:0.1037s
# Local Outleir factor ROC:0.8409, Precision @ rank n:0.325,Execution Time:0.0688s
# Minimum Covariance Determinant ROC:0.7499, Precision @ rank n:0.075,Execution Time:0.6891s
# One-Class SVM ROC:0.5744, Precision @ rank n:0.1,Execution Time:0.0638s
# Principle Component Analysis ROC:0.48, Precision @ rank n:0.05,Execution Time:0.004s
# /n  Processing lympho.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.9382, Precision @ rank n:0.4,Execution Time:0.0209s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.9709, Precision @ rank n:0.6,Execution Time:0.0299s
# FeatureBagging ROC:0.9673, Precision @ rank n:0.6,Execution Time:0.0239s
# Histogram Based Outlier Detection ROC:0.9964, Precision @ rank n:0.8,Execution Time:0.004s
# Isolation Forest ROC:0.9855, Precision @ rank n:0.6,Execution Time:0.2244s
# K-Nearest Neighbour ROC:0.9636, Precision @ rank n:0.6,Execution Time:0.006s
# Local Outleir factor ROC:0.9636, Precision @ rank n:0.6,Execution Time:0.002s
# Minimum Covariance Determinant ROC:0.9164, Precision @ rank n:0.6,Execution Time:0.0259s
# One-Class SVM ROC:0.9636, Precision @ rank n:0.6,Execution Time:0.001s
# Principle Component Analysis ROC:0.9818, Precision @ rank n:0.8,Execution Time:0.0009s
# /n  Processing mnist.mat . . ./n
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-303.881944356529402 > -525.830836350540153). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-304.021763033307082 > -523.143378896311901). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-338.921775030610604 > -381.672782741425522). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# Angle Based Outlier Detection(ABOD) ROC:0.7813, Precision @ rank n:0.3562,Execution Time:5.8135s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.8447, Precision @ rank n:0.4007,Execution Time:0.8228s
# FeatureBagging ROC:0.7259, Precision @ rank n:0.3664,Execution Time:40.6938s
# Histogram Based Outlier Detection ROC:0.5675, Precision @ rank n:0.1199,Execution Time:0.0389s
# Isolation Forest ROC:0.7801, Precision @ rank n:0.2979,Execution Time:1.3932s
# K-Nearest Neighbour ROC:0.8409, Precision @ rank n:0.4144,Execution Time:5.4006s
# Local Outleir factor ROC:0.7085, Precision @ rank n:0.339,Execution Time:4.7792s
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant ROC:0.863, Precision @ rank n:0.3973,Execution Time:1.7413s
# One-Class SVM ROC:0.8417, Precision @ rank n:0.3801,Execution Time:3.752s
# Principle Component Analysis ROC:0.8396, Precision @ rank n:0.3767,Execution Time:0.1107s
# /n  Processing musk.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.0809, Precision @ rank n:0.0333,Execution Time:1.7603s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:1.0, Precision @ rank n:1.0,Execution Time:0.2912s
# FeatureBagging ROC:0.5228, Precision @ rank n:0.1667,Execution Time:10.2725s
# Histogram Based Outlier Detection ROC:0.9999, Precision @ rank n:0.9667,Execution Time:0.0439s
# Isolation Forest ROC:0.9996, Precision @ rank n:0.9333,Execution Time:0.7789s
# K-Nearest Neighbour ROC:0.7348, Precision @ rank n:0.2333,Execution Time:1.3294s
# Local Outleir factor ROC:0.5323, Precision @ rank n:0.1333,Execution Time:1.2766s
# Minimum Covariance Determinant ROC:1.0, Precision @ rank n:0.9667,Execution Time:6.6681s
# One-Class SVM ROC:1.0, Precision @ rank n:1.0,Execution Time:0.9525s
# Principle Component Analysis ROC:1.0, Precision @ rank n:1.0,Execution Time:0.1237s
# /n  Processing optdigits.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.4428, Precision @ rank n:0.0161,Execution Time:1.8531s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.7852, Precision @ rank n:0.0,Execution Time:0.3434s
# FeatureBagging ROC:0.4641, Precision @ rank n:0.0484,Execution Time:11.0524s
# Histogram Based Outlier Detection ROC:0.8822, Precision @ rank n:0.2581,Execution Time:0.0229s
# Isolation Forest ROC:0.5764, Precision @ rank n:0.0161,Execution Time:0.6264s
# K-Nearest Neighbour ROC:0.3824, Precision @ rank n:0.0,Execution Time:1.3484s
# Local Outleir factor ROC:0.4584, Precision @ rank n:0.0484,Execution Time:1.2477s
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant ROC:0.3486, Precision @ rank n:0.0,Execution Time:0.6745s
# One-Class SVM ROC:0.4972, Precision @ rank n:0.0,Execution Time:1.1051s
# Principle Component Analysis ROC:0.504, Precision @ rank n:0.0,Execution Time:0.0299s
# /n  Processing pendigits.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.7008, Precision @ rank n:0.0308,Execution Time:1.0732s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.9609, Precision @ rank n:0.3077,Execution Time:0.2234s
# FeatureBagging ROC:0.4687, Precision @ rank n:0.0462,Execution Time:3.6403s
# Histogram Based Outlier Detection ROC:0.9294, Precision @ rank n:0.2615,Execution Time:0.007s
# Isolation Forest ROC:0.9422, Precision @ rank n:0.2769,Execution Time:0.4987s
# K-Nearest Neighbour ROC:0.7602, Precision @ rank n:0.0462,Execution Time:0.4698s
# Local Outleir factor ROC:0.481, Precision @ rank n:0.0462,Execution Time:0.4418s
# Minimum Covariance Determinant ROC:0.8271, Precision @ rank n:0.0615,Execution Time:1.482s
# One-Class SVM ROC:0.93, Precision @ rank n:0.2923,Execution Time:0.7301s
# Principle Component Analysis ROC:0.9332, Precision @ rank n:0.3385,Execution Time:0.006s
# /n  Processing pima.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.6757, Precision @ rank n:0.5106,Execution Time:0.1546s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.684, Precision @ rank n:0.4681,Execution Time:0.0648s
# FeatureBagging ROC:0.6446, Precision @ rank n:0.4468,Execution Time:0.0748s
# Histogram Based Outlier Detection ROC:0.7169, Precision @ rank n:0.5213,Execution Time:0.003s
# Isolation Forest ROC:0.6604, Precision @ rank n:0.4787,Execution Time:0.2473s
# K-Nearest Neighbour ROC:0.7252, Precision @ rank n:0.5106,Execution Time:0.0259s
# Local Outleir factor ROC:0.6604, Precision @ rank n:0.4787,Execution Time:0.008s
# Minimum Covariance Determinant ROC:0.7047, Precision @ rank n:0.4787,Execution Time:0.0359s
# One-Class SVM ROC:0.6423, Precision @ rank n:0.4574,Execution Time:0.007s
# Principle Component Analysis ROC:0.6639, Precision @ rank n:0.5,Execution Time:0.002s
# /n  Processing satellite.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.5681, Precision @ rank n:0.3918,Execution Time:1.4591s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.7234, Precision @ rank n:0.5574,Execution Time:0.2453s
# FeatureBagging ROC:0.557, Precision @ rank n:0.4051,Execution Time:5.8255s
# Histogram Based Outlier Detection ROC:0.7393, Precision @ rank n:0.5466,Execution Time:0.018s
# Isolation Forest ROC:0.6843, Precision @ rank n:0.5719,Execution Time:0.6014s
# K-Nearest Neighbour ROC:0.6781, Precision @ rank n:0.4994,Execution Time:0.8118s
# Local Outleir factor ROC:0.5551, Precision @ rank n:0.4051,Execution Time:0.755s
# Minimum Covariance Determinant ROC:0.792, Precision @ rank n:0.6747,Execution Time:1.3853s
# One-Class SVM ROC:0.636, Precision @ rank n:0.5224,Execution Time:1.0123s
# Principle Component Analysis ROC:0.5783, Precision @ rank n:0.4559,Execution Time:0.0159s
# /n  Processing satimage-2.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.86, Precision @ rank n:0.2593,Execution Time:1.2118s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.9987, Precision @ rank n:0.8889,Execution Time:0.2114s
# FeatureBagging ROC:0.4971, Precision @ rank n:0.0741,Execution Time:4.87s
# Histogram Based Outlier Detection ROC:0.9837, Precision @ rank n:0.5926,Execution Time:0.014s
# Isolation Forest ROC:0.9962, Precision @ rank n:0.8889,Execution Time:0.5226s
# K-Nearest Neighbour ROC:0.9505, Precision @ rank n:0.3704,Execution Time:0.6632s
# Local Outleir factor ROC:0.5006, Precision @ rank n:0.0741,Execution Time:0.5755s
# Minimum Covariance Determinant ROC:0.9946, Precision @ rank n:0.5185,Execution Time:1.3444s
# One-Class SVM ROC:0.9976, Precision @ rank n:0.9259,Execution Time:0.8418s
# Principle Component Analysis ROC:0.9841, Precision @ rank n:0.8519,Execution Time:0.0149s
# /n  Processing shuttle.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.6186, Precision @ rank n:0.1918,Execution Time:11.1283s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.6287, Precision @ rank n:0.2336,Execution Time:0.6672s
# FeatureBagging ROC:0.5211, Precision @ rank n:0.111,Execution Time:39.07s
# Histogram Based Outlier Detection ROC:0.9851, Precision @ rank n:0.9857,Execution Time:0.013s
# Isolation Forest ROC:0.997, Precision @ rank n:0.9308,Execution Time:2.3148s
# K-Nearest Neighbour ROC:0.645, Precision @ rank n:0.2199,Execution Time:6.3329s
# Local Outleir factor ROC:0.5347, Precision @ rank n:0.1406,Execution Time:9.0442s
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.541490230701029 > -75.592253998160075). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.022992269210960 > -76.150022952275933). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.588090860494539 > -73.997089087121466). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.127165967938033 > -76.814431864511533). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.260339163313560 > -77.183008377260506). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.088727288180451 > -75.865165747812611). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.582785491594258 > -76.611820576922298). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.000544286938101 > -76.202702178617812). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.556584528453953 > -77.098667780846995). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.240104267009002 > -75.051128375205053). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.250211305123095 > -75.269917048873594). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.909548626708364 > -77.316510535945554). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.891326544720059 > -75.752323826887846). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.859327893628439 > -75.506059781784089). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.586488761882819 > -75.469733773072221). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.101075588075524 > -76.262519209035275). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.312636661667774 > -76.827897355973249). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.250066970764166 > -78.448260993170479). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.555505358476601 > -76.383177602584297). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.428222337190036 > -77.657757837885939). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.312868452035886 > -78.275586981066255). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.764724066883446 > -77.282352110428548). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.672481809425953 > -75.780064170775518). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.810409699568289 > -116.332661175263610). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.246740593074648 > -75.373826826201935). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.256978425484292 > -76.476983289741440). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.288199308055468 > -75.990589261846011). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.329968951469141 > -77.419260242705974). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.221834205302052 > -78.090864446968652). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.289029393101089 > -75.757556561107862). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.385618505522793 > -77.171277510572310). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.209250265997660 > -76.818840276676667). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.362224422506152 > -76.716480514242747). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.173137659451463 > -75.808458672225186). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.294483190145293 > -76.390291443926770). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.208972773367584 > -75.741530995676783). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.378081918546030 > -76.605948395137275). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.916820128958108 > -76.552623764140179). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.077545968806284 > -75.696921172394283). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.436632051329951 > -76.438541656063492). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.734734341696203 > -76.521728710156154). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.027942813065295 > -77.260538598709132). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.132819510101456 > -80.575229534353539). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\narkh\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.826679532509623 > -77.642101236679707). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# Minimum Covariance Determinant ROC:0.9903, Precision @ rank n:0.7534,Execution Time:8.0943s
# One-Class SVM ROC:0.9922, Precision @ rank n:0.9553,Execution Time:34.428s
# Principle Component Analysis ROC:0.9902, Precision @ rank n:0.9503,Execution Time:0.023s
# /n  Processing vertebral.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.2797, Precision @ rank n:0.0,Execution Time:0.0479s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.3908, Precision @ rank n:0.0,Execution Time:0.0429s
# FeatureBagging ROC:0.3027, Precision @ rank n:0.0,Execution Time:0.0289s
# Histogram Based Outlier Detection ROC:0.2695, Precision @ rank n:0.0,Execution Time:0.001s
# Isolation Forest ROC:0.3576, Precision @ rank n:0.0,Execution Time:0.2374s
# K-Nearest Neighbour ROC:0.318, Precision @ rank n:0.0,Execution Time:0.007s
# Local Outleir factor ROC:0.318, Precision @ rank n:0.0,Execution Time:0.002s
# Minimum Covariance Determinant ROC:0.3308, Precision @ rank n:0.0,Execution Time:0.0299s
# One-Class SVM ROC:0.4087, Precision @ rank n:0.0,Execution Time:0.001s
# Principle Component Analysis ROC:0.3397, Precision @ rank n:0.0,Execution Time:0.0009s
# /n  Processing vowels.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.9521, Precision @ rank n:0.4706,Execution Time:0.2483s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.9278, Precision @ rank n:0.4118,Execution Time:0.0858s
# FeatureBagging ROC:0.9385, Precision @ rank n:0.3529,Execution Time:0.2553s
# Histogram Based Outlier Detection ROC:0.6758, Precision @ rank n:0.1765,Execution Time:0.003s
# Isolation Forest ROC:0.6933, Precision @ rank n:0.1765,Execution Time:0.2802s
# K-Nearest Neighbour ROC:0.9568, Precision @ rank n:0.5294,Execution Time:0.0568s
# Local Outleir factor ROC:0.9345, Precision @ rank n:0.4118,Execution Time:0.0269s
# Minimum Covariance Determinant ROC:0.6779, Precision @ rank n:0.0,Execution Time:0.5076s
# One-Class SVM ROC:0.7415, Precision @ rank n:0.2941,Execution Time:0.0299s
# Principle Component Analysis ROC:0.5787, Precision @ rank n:0.1176,Execution Time:0.002s
# /n  Processing wbc.mat . . ./n
# Angle Based Outlier Detection(ABOD) ROC:0.9232, Precision @ rank n:0.3,Execution Time:0.0788s
# Cluster-Based Local Outlier Factor(CBLOF) ROC:0.9063, Precision @ rank n:0.6,Execution Time:0.0598s
# FeatureBagging ROC:0.9415, Precision @ rank n:0.5,Execution Time:0.0758s
# Histogram Based Outlier Detection ROC:0.9592, Precision @ rank n:0.7,Execution Time:0.0099s
# Isolation Forest ROC:0.9451, Precision @ rank n:0.5,Execution Time:0.2463s
# K-Nearest Neighbour ROC:0.9437, Precision @ rank n:0.5,Execution Time:0.0159s
# Local Outleir factor ROC:0.9352, Precision @ rank n:0.4,Execution Time:0.0059s
# Minimum Covariance Determinant ROC:0.8986, Precision @ rank n:0.4,Execution Time:0.0429s
# One-Class SVM ROC:0.9408, Precision @ rank n:0.5,Execution Time:0.004s
# Principle Component Analysis ROC:0.9324, Precision @ rank n:0.6,Execution Time:0.002s

# %%
roc_df
# Out:
#          Data #Samples #Dimensions Outlier Perc    ABOD   CBLOF      FB  \
# 0  arrhythmia      452         274      14.6018  0.7687  0.7684  0.7799
# 0      cardio     1831          21       9.6122  0.5763  0.8221  0.4879
# 0       glass      214           9       4.2056  0.7104  0.8506  0.7043
# 0  ionosphere      351          33      35.8974  0.9004  0.8952  0.8933
# 0      letter     1600          32         6.25  0.8465  0.7423   0.866
# 0      lympho      148          18       4.0541  0.9382  0.9709  0.9673
# 0       mnist     7603         100       9.2069  0.7813  0.8447  0.7259
# 0        musk     3062         166       3.1679  0.0809       1  0.5228
# 0   optdigits     5216          64       2.8758  0.4428  0.7852  0.4641
# 0   pendigits     6870          16       2.2707  0.7008  0.9609  0.4687
# 0        pima      768           8      34.8958  0.6757   0.684  0.6446
# 0   satellite     6435          36      31.6395  0.5681  0.7234   0.557
# 0  satimage-2     5803          36       1.2235    0.86  0.9987  0.4971
# 0     shuttle    49097           9       7.1511  0.6186  0.6287  0.5211
# 0   vertebral      240           6         12.5  0.2797  0.3908  0.3027
# 0      vowels     1456          12       3.4341  0.9521  0.9278  0.9385
# 0         wbc      378          30       5.5556  0.9232  0.9063  0.9415
#
#      HBOS IForest     KNN     LOF     MCD   OCSVM     PCA
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986  0.7997
# 0  0.8453  0.9414  0.6959  0.4715  0.8778  0.9507  0.9638
# 0  0.6524  0.7195  0.7805  0.7774  0.7165  0.6189   0.622
# 0  0.5195  0.8309  0.9134  0.8989  0.9399  0.8372  0.7971
# 0  0.5728  0.5778   0.845  0.8409  0.7499  0.5744    0.48
# 0  0.9964  0.9855  0.9636  0.9636  0.9164  0.9636  0.9818
# 0  0.5675  0.7801  0.8409  0.7085   0.863  0.8417  0.8396
# 0  0.9999  0.9996  0.7348  0.5323       1       1       1
# 0  0.8822  0.5764  0.3824  0.4584  0.3486  0.4972   0.504
# 0  0.9294  0.9422  0.7602   0.481  0.8271    0.93  0.9332
# 0  0.7169  0.6604  0.7252  0.6604  0.7047  0.6423  0.6639
# 0  0.7393  0.6843  0.6781  0.5551   0.792   0.636  0.5783
# 0  0.9837  0.9962  0.9505  0.5006  0.9946  0.9976  0.9841
# 0  0.9851   0.997   0.645  0.5347  0.9903  0.9922  0.9902
# 0  0.2695  0.3576   0.318   0.318  0.3308  0.4087  0.3397
# 0  0.6758  0.6933  0.9568  0.9345  0.6779  0.7415  0.5787
# 0  0.9592  0.9451  0.9437  0.9352  0.8986  0.9408  0.9324
